# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st

# %%
# Using exponential() method
Data = np.random.exponential(50, 200)
  
count, bins, ignored = plt.hist(Data, 5, density = True)

plt.xlabel('Distance From Release Site')
plt.ylabel('Peak DA Concentration')
plt.legend(['Simulated'])

plt.show()
